# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df1=pd.read_csv(r'C:\Users\User\Desktop\Tesla (TSLA) From 2010 To Dec-2024.csv')
df1.head(4)
# Out:
#                         Date      Open      High       Low     Close  \
# 0  2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1  2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2  2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3  2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
#
#       Volume
# 0  281494500
# 1  257806500
# 2  123282000
# 3   77097000

# %%
df2=pd.read_csv(r'C:\Users\User\Desktop\Apple (AAPL) From 1980 To Dec-2024.csv')
df2.head(4)
# Out:
#                         Date      Open      High       Low     Close  \
# 0  1980-12-12 00:00:00-05:00  0.098834  0.099264  0.098834  0.098834
# 1  1980-12-15 00:00:00-05:00  0.094108  0.094108  0.093678  0.093678
# 2  1980-12-16 00:00:00-05:00  0.087232  0.087232  0.086802  0.086802
# 3  1980-12-17 00:00:00-05:00  0.088951  0.089381  0.088951  0.088951
#
#       Volume
# 0  469033600
# 1  175884800
# 2  105728000
# 3   86441600

# %%
df=df1.merge(df2,on='Date',how='inner')
df.head(4)
# Out:
#                         Date    Open_x    High_x     Low_x   Close_x  \
# 0  2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1  2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2  2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3  2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
#
#     Volume_x    Open_y    High_y     Low_y   Close_y    Volume_y
# 0  281494500  7.957058  7.965193  7.661214  7.717551  1133344800
# 1  257806500  7.733820  7.771780  7.531973  7.577765   739452000
# 2  123282000  7.661216  7.676279  7.327413  7.485878  1022896000
# 3   77097000  7.546432  7.559689  7.326809  7.439484   693842800

# %%
df=df.rename(columns={'Close_x':'Tesla Profit','Close_y':'Apple Profit'})
df.head(4)
# Out:
#                         Date    Open_x    High_x     Low_x  Tesla Profit  \
# 0  2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333      1.592667
# 1  2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333      1.588667
# 2  2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333      1.464000
# 3  2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333      1.280000
#
#     Volume_x    Open_y    High_y     Low_y  Apple Profit    Volume_y
# 0  281494500  7.957058  7.965193  7.661214      7.717551  1133344800
# 1  257806500  7.733820  7.771780  7.531973      7.577765   739452000
# 2  123282000  7.661216  7.676279  7.327413      7.485878  1022896000
# 3   77097000  7.546432  7.559689  7.326809      7.439484   693842800

# %%
#df.set_index('Date')
#df=df.drop(columns='index')

# %%
df.head(4)
type(df['Date'][2])
# Out:
# str

# %%
df['Date'].astype('str')
date=df['Date'].str.split(' ',n=1,expand=True)
date.head(4)
# Out:
#             0               1
# 0  2010-06-29  00:00:00-04:00
# 1  2010-06-30  00:00:00-04:00
# 2  2010-07-01  00:00:00-04:00
# 3  2010-07-02  00:00:00-04:00

# %%
date=date.rename(columns={0:'Year',1:'Date'})
date.head(4)
# Out:
#          Year            Date
# 0  2010-06-29  00:00:00-04:00
# 1  2010-06-30  00:00:00-04:00
# 2  2010-07-01  00:00:00-04:00
# 3  2010-07-02  00:00:00-04:00

# %%
#df=df.drop(columns='Date')

# %%
df.head(4)
# Out:
#                         Date    Open_x    High_x     Low_x  Tesla Profit  \
# 0  2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333      1.592667
# 1  2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333      1.588667
# 2  2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333      1.464000
# 3  2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333      1.280000
#
#     Volume_x    Open_y    High_y     Low_y  Apple Profit    Volume_y
# 0  281494500  7.957058  7.965193  7.661214      7.717551  1133344800
# 1  257806500  7.733820  7.771780  7.531973      7.577765   739452000
# 2  123282000  7.661216  7.676279  7.327413      7.485878  1022896000
# 3   77097000  7.546432  7.559689  7.326809      7.439484   693842800

# %%
#df=df.join(date)

# %%
df.head(4)
# Out:
#                         Date    Open_x    High_x     Low_x  Tesla Profit  \
# 0  2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333      1.592667
# 1  2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333      1.588667
# 2  2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333      1.464000
# 3  2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333      1.280000
#
#     Volume_x    Open_y    High_y     Low_y  Apple Profit    Volume_y
# 0  281494500  7.957058  7.965193  7.661214      7.717551  1133344800
# 1  257806500  7.733820  7.771780  7.531973      7.577765   739452000
# 2  123282000  7.661216  7.676279  7.327413      7.485878  1022896000
# 3   77097000  7.546432  7.559689  7.326809      7.439484   693842800

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv(r'C:\Users\User\Desktop\Clean Apple and Tesla Data.csv')

# %%
df.head(4)
# Out:
#                         Date    Open_x    High_x     Low_x  Tesla Profit  \
# 0  2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333      1.592667
# 1  2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333      1.588667
# 2  2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333      1.464000
# 3  2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333      1.280000
#
#     Volume_x    Open_y    High_y     Low_y  Apple Profit    Volume_y
# 0  281494500  7.957058  7.965193  7.661214      7.717551  1133344800
# 1  257806500  7.733820  7.771780  7.531973      7.577765   739452000
# 2  123282000  7.661216  7.676279  7.327413      7.485878  1022896000
# 3   77097000  7.546432  7.559689  7.326809      7.439484   693842800

# %%
df1=pd.read_csv(r'C:\Users\User\Desktop\Clean Apple and Tesla Data.csv')
df1.head(4)
# Out:
#      Open_x    High_x     Low_x  Tesla Profit   Volume_x    Open_y    High_y  \
# 0  1.266667  1.666667  1.169333      1.592667  281494500  7.957058  7.965193
# 1  1.719333  2.028000  1.553333      1.588667  257806500  7.733820  7.771780
# 2  1.666667  1.728000  1.351333      1.464000  123282000  7.661216  7.676279
# 3  1.533333  1.540000  1.247333      1.280000   77097000  7.546432  7.559689
#
#       Low_y  Apple Profit    Volume_y         Year   Time
# 0  7.661214      7.717551  1133344800  29-Jun-2010  04:00
# 1  7.531973      7.577765   739452000  30-Jun-2010  04:00
# 2  7.327413      7.485878  1022896000   1-Jul-2010  04:00
# 3  7.326809      7.439484   693842800   2-Jul-2010  04:00

# %%
x1=pd.DataFrame({'Year':df1['Year'],'Tesla Profit':df1['Tesla Profit'],'Apple Profit':df1['Apple Profit']})
x1=x1.set_index('Year')
x1
# Out:
#              Tesla Profit  Apple Profit
# Year
# 29-Jun-2010      1.592667      7.717551
# 30-Jun-2010      1.588667      7.577765
# 1-Jul-2010       1.464000      7.485878
# 2-Jul-2010       1.280000      7.439484
# 6-Jul-2010       1.074000      7.490399
# ...                   ...           ...
# 22-Nov-2024    352.559998    229.869995
# 25-Nov-2024    338.589996    232.869995
# 26-Nov-2024    338.230011    235.059998
# 27-Nov-2024    332.890015    234.929993
# 29-Nov-2024    345.160004    237.330002
#
# [3631 rows x 2 columns]

# %%
plt.style.use('ggplot')
x1.plot.line(xlabel='Year',ylabel='Tesla & Apple Profit',title='Price Trend Comparison',figsize=(20,10))
# Out:
# <Axes: title={'center': 'Price Trend Comparison'}, xlabel='Year', ylabel='Tesla & Apple Profit'>

# %% [markdown]
# # Tesla and Apple Daily & weekly Return

# %%
Y1=df1
df1.head(4)
# Out:
#      Open_x    High_x     Low_x  Tesla Profit   Volume_x    Open_y    High_y  \
# 0  1.266667  1.666667  1.169333      1.592667  281494500  7.957058  7.965193
# 1  1.719333  2.028000  1.553333      1.588667  257806500  7.733820  7.771780
# 2  1.666667  1.728000  1.351333      1.464000  123282000  7.661216  7.676279
# 3  1.533333  1.540000  1.247333      1.280000   77097000  7.546432  7.559689
#
#       Low_y  Apple Profit    Volume_y         Year   Time
# 0  7.661214      7.717551  1133344800  29-Jun-2010  04:00
# 1  7.531973      7.577765   739452000  30-Jun-2010  04:00
# 2  7.327413      7.485878  1022896000   1-Jul-2010  04:00
# 3  7.326809      7.439484   693842800   2-Jul-2010  04:00

# %%
Tesla_Profit_Return=x1['Tesla Profit'].pct_change()
Tesla_Profit_Return
Apple_Profit_Return=x1['Apple Profit'].pct_change()
Apple_Profit_Return
X=pd.DataFrame({'Tesla_Profit_Return':Tesla_Profit_Return,'Apple_Profit_Return':Apple_Profit_Return})
X
# Out:
#              Tesla_Profit_Return  Apple_Profit_Return
# Year
# 29-Jun-2010                  NaN                  NaN
# 30-Jun-2010            -0.002511            -0.018113
# 1-Jul-2010             -0.078473            -0.012126
# 2-Jul-2010             -0.125683            -0.006198
# 6-Jul-2010             -0.160937             0.006844
# ...                          ...                  ...
# 22-Nov-2024             0.038040             0.005908
# 25-Nov-2024            -0.039624             0.013051
# 26-Nov-2024            -0.001063             0.009404
# 27-Nov-2024            -0.015788            -0.000553
# 29-Nov-2024             0.036859             0.010216
#
# [3631 rows x 2 columns]

# %%
df3=X[['Tesla_Profit_Return','Apple_Profit_Return']].round(4)
df3
# Out:
#              Tesla_Profit_Return  Apple_Profit_Return
# Year
# 29-Jun-2010                  NaN                  NaN
# 30-Jun-2010              -0.0025              -0.0181
# 1-Jul-2010               -0.0785              -0.0121
# 2-Jul-2010               -0.1257              -0.0062
# 6-Jul-2010               -0.1609               0.0068
# ...                          ...                  ...
# 22-Nov-2024               0.0380               0.0059
# 25-Nov-2024              -0.0396               0.0131
# 26-Nov-2024              -0.0011               0.0094
# 27-Nov-2024              -0.0158              -0.0006
# 29-Nov-2024               0.0369               0.0102
#
# [3631 rows x 2 columns]

# %%
#plt.style.available

# %%
plt.style.use('_mpl-gallery')
df3.plot.line(xlabel='Year',ylabel='Profit Return',title='Tesla & Apple Profit Return',figsize=(20,10),color=('red','black'))
plt.title('Tesla & Apple Profit Return',color='black',size=24)
plt.xlabel('Year',color='black',size=24)
plt.ylabel('Profit Return',color='black',size=24)
plt.xticks(fontsize=20,color='black')
plt.yticks(fontsize=20,color='black')
plt.legend(fontsize=15)

# %% [markdown]
# # Correlation btwn Apple and Tesla

# %%
df_Tesla=pd.read_csv(r'C:\Users\User\Desktop\Tesla (TSLA) From 2010 To Dec-2024.csv')
df_Tesla.head(4)
# Out:
#                         Date      Open      High       Low     Close  \
# 0  2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1  2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2  2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3  2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
#
#       Volume
# 0  281494500
# 1  257806500
# 2  123282000
# 3   77097000

# %%
df_Apple=pd.read_csv(r'C:\Users\User\Desktop\Apple (AAPL) From 1980 To Dec-2024.csv')
df_Apple.head(4)
# Out:
#                         Date      Open      High       Low     Close  \
# 0  1980-12-12 00:00:00-05:00  0.098834  0.099264  0.098834  0.098834
# 1  1980-12-15 00:00:00-05:00  0.094108  0.094108  0.093678  0.093678
# 2  1980-12-16 00:00:00-05:00  0.087232  0.087232  0.086802  0.086802
# 3  1980-12-17 00:00:00-05:00  0.088951  0.089381  0.088951  0.088951
#
#       Volume
# 0  469033600
# 1  175884800
# 2  105728000
# 3   86441600

# %%
X.head(4)
# Out:
#              Tesla_Profit_Return  Apple_Profit_Return
# Year
# 29-Jun-2010                  NaN                  NaN
# 30-Jun-2010            -0.002511            -0.018113
# 1-Jul-2010             -0.078473            -0.012126
# 2-Jul-2010             -0.125683            -0.006198

# %% [markdown]
# # Relationship btwn Tesla Profit Return and Apple Profit Return is Weak

# %%
X['Tesla_Profit_Return'].corr(X['Apple_Profit_Return'])
# Out:
# 0.3549402125312573

# %% [markdown]
# # Volatility Rate

# %%
df1['Tesla Profit'].std()
# Out:
# 104.83684124446636

# %%
df1['Apple Profit'].std()
# Out:
# 64.5564893365752

# %% [markdown]
# # Conclusion: Volatity Rate of Tesla is higher than that of Apple
